# %%
import ml_outputs as mo
import pandas as pd

# %%
df = pd.read_csv('cleaned_tvg_cd_data.csv')
df.tail()
# Out:
#        racedater tvgtrackcode  race  bettinginterestnumber      horsename  \
# 1992  2020-05-29           cd     9                      7       out cold
# 1993  2020-05-29           cd     9                      8   irish spirit
# 1994  2020-05-29           cd     9                      9  alex's strike
# 1995  2020-05-29           cd     9                     10   heros reward
# 1996  2020-05-29           cd     9                     11     nice of me
#
#       morninglineodds currentodds  tvghorseweight tvghorsedamsirename  \
# 1992             20.0          SC             123     northern afleet
# 1993              3.0           3             123         forest camp
# 1994              8.0           4             123        smart strike
# 1995             10.0           2             118        smart strike
# 1996             20.0          19             123    allen's prospect
#
#       tvghorseage  ... tvghorsenumberofwins  tvghorsenumberofstarts  \
# ...

# %%
features = [
    'tvghorseweight',            # 0
    'tvghorseage',               # 1
    'tvghorsedaysoff',           # 2
    'tvghorsenumberofwins',      # 3
    'tvghorsepowerrating',       # 4
    'tvghorseaverageclassrating' # 5
]

X= df[features]
y= df.tvghorseaveragespeed.values.reshape(-1,1)

X_train, X_test, y_train, y_test = mo.splitter(X=X, y=y).splitting_function()

# %%
X_train_scaled, X_test_scaled = mo.scaler.X_scaler_function(X_train,X_test)

# %%
y_train_scaled, y_test_scaled = mo.scaler.y_scaler_function(y_train,y_test)

# %%
lin_reg = mo.regression_models.linear_regression(X_train_scaled, 
                                                 X_test_scaled,
                                                 y_train_scaled, 
                                                 y_test_scaled)

# %%
lasso =mo.regression_models.lasso(X_train_scaled, 
                                     X_test_scaled,
                                     y_train_scaled, 
                                     y_test_scaled)

# %%
ridge = mo.regression_models.ridge(X_train_scaled, 
                                     X_test_scaled,
                                     y_train_scaled, 
                                     y_test_scaled)

# %%
elas = mo.regression_models.elastic_net(X_train_scaled, 
                                         X_test_scaled,
                                         y_train_scaled, 
                                         y_test_scaled)
