# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
raw_data = pd.read_csv(os.path.join('..','data','Gp_200502_hr.csv'))
raw_data.describe()
# Out:
#             RCRace  Foreign         Race     Distance   ClaimPrice  \
# count  1362.000000      0.0  1362.000000  1362.000000  1362.000000
# mean      7.463289      NaN     6.103524     7.007783    16.447871
# std       3.441616      NaN     2.962713     1.182487    19.756230
# min       1.000000      NaN     0.000000     4.500000     0.000000
# 25%       5.000000      NaN     4.000000     6.000000     0.000000
# 50%       7.000000      NaN     6.000000     7.000000    10.000000
# 75%      11.000000      NaN     8.000000     8.000000    25.000000
# max      12.000000      NaN    14.000000    10.000000   100.000000
#
#              Purse      RaceAge     Starters  FirstFraction  SecondFraction  \
# count  1362.000000  1362.000000  1362.000000    1362.000000     1362.000000
# mean     49.407156    22.591043     8.488253      22.998678       46.869604
# std      66.943001    15.499217     2.075063       4.722292       10.714250
# ...

# %%
columns = [
    'Horse',
    'Distance',
    'Starters',
    'FirstFraction',
    'SecondFraction',
    'ThirdFraction',
    'FourthFraction',
    'FifthFraction',
    'SixthFraction',
    'FinalTime',
    'FirstWeight',
    'SecondWeight',
    'ThirdWeight',
    'FirstLenAdj',
    'SecondLenAdj',
    'ThirdLenAdj',
    'PostPosition',
    'FirstCall',
    'FirstCallLenAdj',
    'SecondCall',
    'SecondCallLenAdj',
    'ThirdCall',
    'ThirdCallLenAdj',
    'FourthCall',
    'FourthCallLenAdj',
    'StrCall',
    'StrCallLenAdj',
    'FinalCall',
    'FinalCallLenAdj',
    'Beyer',
    'Weight',
    'Odds',
    'OddsPosition',
    'FirstFracHdths',
    'SecondFracHdths',
    'ThirdFracHdths',
    'FourthFracHdths',
    'FifthFracHdths',
    'SixthFracHdths',
    'FinalTimeHdths'
]

# %%
data = raw_data[columns]
data.head()
# Out:
#                 Horse  Distance  Starters  FirstFraction  SecondFraction  \
# 0          Wind Ridge      8.50         8           23.8            47.2
# 1          Wind Ridge      8.18         8           23.6            47.4
# 2  Constitutional Pal      8.00         9           22.0            45.4
# 3  Constitutional Pal      6.00         7           22.6            46.0
# 4       Elusive Ruler      9.00        10           48.2           113.2
#
#    ThirdFraction  FourthFraction  FifthFraction  SixthFraction  FinalTime  \
# 0          111.4           136.6           -1.0           -1.0      143.2
# 1          111.6           137.2           -1.0           -1.0      139.4
# 2          109.8            -1.0           -1.0           -1.0      134.4
# 3           58.6            -1.0           -1.0           -1.0      111.8
# 4          138.6           138.6           -1.0           -1.0      152.0
#
#    ...  Weight  Odds  OddsPosition  FirstFracHdths  SecondFracHdths  \
# ...

# %%
pd.set_option('display.max_rows', data.shape[0]+1)
data['Beyer'].value_counts()
# h = columns[0]
# globals()columns[0]
# print(p)
# for i in columns:
#     print(i)
#     print(data[i].value_counts())
#     print('------------------------------')
# Out:
#  69     60
#  70     44
#  74     43
#  73     42
#  68     42
#  65     40
#  64     40
#  71     35
#  72     34
#  66     34
#  54     33
#  78     32
#  61     32
#  75     32
#  62     31
#  67     30
#  63     29
#  59     28
#  76     28
#  55     25
#  52     25
#  60     24
#  56     23
#  79     22
#  77     22
#  58     21
#  50     21
#  80     18
#  51     18
#  53     17
#  81     17
#  57     17
#  82     16
#  45     15
#  47     14
#  46     14
#  0      14
#  84     14
#  83     13
#  48     13
#  34     12
#  37     12
#  91     12
#  49     12
#  44     11
#  85     11
#  86     11
#  89     11
#  40     11
#  42     11
#  39     10
#  38      9
#  41      9
#  35      9
#  90      9
#  87      8
#  998     8
#  32      7
#  36      6
#  29      6
#  31      6
#  88      6
#  27      5
#  43      5
#  95      5
#  30      5
# -1       4
#  92      4
#  15      4
#  14      4
#  18      3
#  23      3
#  19      3
#  12      3
#  21      3
#  26      3
# ...

# %%
features = [
#     'Horse',
    'Distance',
    'Starters',
    'FirstFraction',
    'SecondFraction',
    'ThirdFraction',
    'FourthFraction',
    'FifthFraction',
    'SixthFraction',
    'FinalTime',
    'FirstWeight',
    'SecondWeight',
    'ThirdWeight',
    'FirstLenAdj',
    'SecondLenAdj',
    'ThirdLenAdj',
    'PostPosition',
    'FirstCall',
    'FirstCallLenAdj',
    'SecondCall',
    'SecondCallLenAdj',
    'ThirdCall',
    'ThirdCallLenAdj',
    'FourthCall',
    'FourthCallLenAdj',
    'StrCall',
    'StrCallLenAdj',
    'FinalCall',
    'FinalCallLenAdj',
#     'Beyer',
    'Weight',
    'Odds',
    'OddsPosition',
    'FirstFracHdths',
    'SecondFracHdths',
    'ThirdFracHdths',
    'FourthFracHdths',
    'FifthFracHdths',
    'SixthFracHdths',
    'FinalTimeHdths'
]

X = data[features]
y = data.Beyer.values.reshape(-1,1)

# %%
X.head()
# Out:
#    Distance  Starters  FirstFraction  SecondFraction  ThirdFraction  \
# 0      8.50         8           23.8            47.2          111.4
# 1      8.18         8           23.6            47.4          111.6
# 2      8.00         9           22.0            45.4          109.8
# 3      6.00         7           22.6            46.0           58.6
# 4      9.00        10           48.2           113.2          138.6
#
#    FourthFraction  FifthFraction  SixthFraction  FinalTime  FirstWeight  ...  \
# 0           136.6           -1.0           -1.0      143.2          118  ...
# 1           137.2           -1.0           -1.0      139.4          120  ...
# 2            -1.0           -1.0           -1.0      134.4          119  ...
# 3            -1.0           -1.0           -1.0      111.8          119  ...
# 4           138.6           -1.0           -1.0      152.0          122  ...
#
#    Weight  Odds  OddsPosition  FirstFracHdths  SecondFracHdths  \
# ...

# %%
y
# Out:
# array([[65],
#        [60],
#        [51],
#        ...,
#        [ 5],
#        [56],
#        [37]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.8, random_state=42)

# %%
print(f'''
X_train: {X_train[:10]} \n
y_train: {y_train[:10]} \n
X_test: {X_test[:10]} \n
y_test: {y_test[:10]}
''')
# Out:
# X_train:       Distance  Starters  FirstFraction  SecondFraction  ThirdFraction  \
# 1069       7.0         8           23.2            47.4          113.2
# 476        5.5         9           21.8            45.2           58.2
# 157        8.0         9           23.2            46.2          111.8
# 16         8.0         9           24.2            48.6          114.2
# 1072       8.0        11           22.6            45.6          109.2
# 546        5.0         6           -1.0            -1.0           -1.0
# 658        8.0         6           23.0            46.2          110.2
# 1119       5.0        11           22.8            46.0           -1.0
# 1019       7.0        10           22.4            45.4          110.6
# 1144       5.5         6           23.0            47.2           59.0
#
#       FourthFraction  FifthFraction  SixthFraction  FinalTime  FirstWeight  \
# 1069            -1.0           -1.0           -1.0      126.6          118
# ...

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)
train_score = model.score(X_train,y_train)
test_score = model.score(X_test,y_test)

# %%
print(f'''
Test Score: {train_score}
Train Score: {test_score}
''')
# Out:
# Test Score: 0.529970509526568
# Train Score: -0.8456148955554164

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

model = make_pipeline(StandardScaler(), SVC(kernel='linear',gamma='auto'))
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(gamma='auto', kernel='linear'))])

# %%
model.score(X_test,y_test)
# Out:
# 0.046788990825688076

# %%
from sklearn.svm import SVC
kernals = ['linear', 'poly','rbf', 'sigmoid']
f = []
for i in kernals:    
    for j in features:
        print(f'kernal: {i}')
        model = SVC(kernel=i)
        f.append(j)
#         print(f)
        num_feats=len(f)
        print(f'Number of Features: {num_feats}')
        model.fit(X_train[f],y_train)
        train_score = model.score(X_train[f],y_train)
        print(f'Train Score: {score}')
        test_score = model.score(X_test[f],y_test)
        print(f'Test Score: {test_score}')
        print('--------------------------------')
# Out:
# kernal: linear
# Number of Features: 1
# Train Score: 0.0625
# Test Score: 0.03944954128440367
# --------------------------------
# kernal: linear
# Number of Features: 2
# Train Score: 0.0625
# Test Score: 0.04128440366972477
# --------------------------------
# kernal: linear
# Number of Features: 3
# Train Score: 0.0625
# Test Score: 0.043119266055045874
# --------------------------------
# kernal: linear
# Number of Features: 4
# Train Score: 0.0625
# Test Score: 0.044954128440366975
# --------------------------------
# kernal: linear
# Number of Features: 5
# Train Score: 0.0625
# Test Score: 0.03669724770642202
# --------------------------------
# kernal: linear
# Number of Features: 6
# Train Score: 0.0625
# Test Score: 0.029357798165137616
# --------------------------------
# kernal: linear
# Number of Features: 7
# Train Score: 0.0625
# Test Score: 0.029357798165137616
# --------------------------------
# kernal: linear
# Number of Features: 8
# Train Score: 0.0625
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=6, activation='relu', input_dim=2))
model.add(Dense(units=2, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 6)                 18
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 14
# ...
# Total params: 32
# Trainable params: 32
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(
    X_train,
    y_train,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-4ba3b4d54fbe> in <module>
#       8     epochs=100,
#       9     shuffle=True,
# ---> 10     verbose=2
#      11 )
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ...
