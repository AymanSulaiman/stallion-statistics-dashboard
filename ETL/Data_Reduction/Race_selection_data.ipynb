# %%
import pandas as pd

# %%
fullcard = pd.read_csv("../Data/Op_200502_r.csv")

# %%
fullcard
# Out:
#    RCTrack      RCDate  RCRace  Starters     TrackName RaceState  Division  \
# 0       OP  05/02/2020       1        12  Oaklawn Park        AR       NaN
# 1       OP  05/02/2020       2        14  Oaklawn Park        AR       NaN
# 2       OP  05/02/2020       3        14  Oaklawn Park        AR       NaN
# 3       OP  05/02/2020       4        14  Oaklawn Park        AR       NaN
# 4       OP  05/02/2020       5        13  Oaklawn Park        AR       NaN
# 5       OP  05/02/2020       6        14  Oaklawn Park        AR       NaN
# 6       OP  05/02/2020       7        14  Oaklawn Park        AR       NaN
# 7       OP  05/02/2020       8        14  Oaklawn Park        AR       NaN
# 8       OP  05/02/2020       9        14  Oaklawn Park        AR       NaN
# 9       OP  05/02/2020      10        14  Oaklawn Park        AR       NaN
# 10      OP  05/02/2020      11        11  Oaklawn Park        AR       NaN
# 11      OP  05/02/2020      12        14  Oaklawn Park        AR       NaN
# 12      OP  05/02/2020      13        11  Oaklawn Park        AR       NaN
# 13      OP  05/02/2020      14        14  Oaklawn Park        AR       NaN
#
#     RaceBred StateBred RaceSex  ...  SimTrack SimRace  TrackRecord  DayOfWeek  \
# 0        NaN       NaN       M  ...       NaN       0        107.8   Saturday
# 1        NaN       NaN       F  ...       NaN       0        107.8   Saturday
# 2        NaN         S       O  ...       NaN       0        107.8   Saturday
# 3        NaN       NaN       O  ...       NaN       0        107.8   Saturday
# 4        NaN       NaN       O  ...       NaN       0        140.2   Saturday
# 5        NaN       NaN       O  ...       NaN       0        146.6   Saturday
# 6        NaN       NaN       F  ...       NaN       0        140.2   Saturday
# 7        NaN       NaN       O  ...       NaN       0        140.2   Saturday
# 8        NaN       NaN       O  ...       NaN       0        140.2   Saturday
# 9        NaN       NaN       O  ...       NaN       0        140.2   Saturday
# 10       NaN       NaN       O  ...       NaN       0        146.6   Saturday
# 11       NaN       NaN       O  ...       NaN       0        146.6   Saturday
# 12       NaN       NaN       O  ...       NaN       0        146.6   Saturday
# 13       NaN       NaN       O  ...       NaN       0        258.0   Saturday
#
#     PostTime     LongClass     TrkAbbrev DistUnit  TimeUnit  \
# 0      12:00    Alw 40000s  Oaklawn Park      NaN         H
# 1      12:32  Md Sp Wt 60k  Oaklawn Park      NaN         H
# 2       1:04  Alw 61000N$Y  Oaklawn Park      NaN         H
# 3       1:36  Md Sp Wt 60k  Oaklawn Park      NaN         H
# 4       2:10      OC 75k/C  Oaklawn Park      NaN         H
# 5       2:44  Md Sp Wt 60k  Oaklawn Park      NaN         H
# 6       3:16     OC 100k/C  Oaklawn Park      NaN         H
# 7       3:47  Alw 61000N$Y  Oaklawn Park      NaN         H
# 8       4:19    OC 40k/N$Y  Oaklawn Park      NaN         H
# 9       4:54    OC 80k/N$Y  Oaklawn Park      NaN         H
# 10      5:29   ArkDerby-G1  Oaklawn Park      NaN         H
# 11      6:04   OaklawnH-G2  Oaklawn Park      NaN         H
# 12      6:43   ArkDerby-G1  Oaklawn Park      NaN         H
# 13      7:14    Alw 10000s  Oaklawn Park      NaN         H
#
#                                            Conditions
# 0   STARTER ALLOWANCE. Purse $32,000  FOR FILLIES ...
# 1   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 2   ALLOWANCE. Purse $61,000  FOR ARKANSAS BRED (W...
# 3   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 4   ALLOWANCE OPTIONAL CLAIMING. Purse $62,000  FO...
# 5   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 6   ALLOWANCE OPTIONAL CLAIMING. Purse $61,000  FO...
# 7   ALLOWANCE. Purse $61,000  FOR THREE YEAR OLDS ...
# 8   ALLOWANCE OPTIONAL CLAIMING. Purse $62,000  FO...
# 9   ALLOWANCE OPTIONAL CLAIMING. Purse $61,000  FO...
# 10  ARKANSAS DERBY. Purse $500,000  THREE YEAR OLD...
# 11  OAKLAWN H.. Purse $600,000  FOUR YEAR OLDS AND...
# 12  ARKANSAS DERBY. Purse $500,000  THREE YEAR OLD...
# 13  STARTER ALLOWANCE. Purse $50,000  FOR THREE YE...
#
# [14 rows x 31 columns]

# %%
for col in fullcard.columns: 
    print(col)
# Out:
# RCTrack
# RCDate
# RCRace
# Starters
# TrackName
# RaceState
# Division
# RaceBred
# StateBred
# RaceSex
# RaceAge
# Class
# Purse
# HiClaim
# LoClaim
# Distance
# Inner
# Surface
# RaceType
# GradedRace
# GradedRaceDesc
# SimTrack
# SimRace
# TrackRecord
# DayOfWeek
# PostTime
# LongClass
# TrkAbbrev
# DistUnit
# TimeUnit
# Conditions

# %%
slim_df = fullcard.drop(columns=[
'TrackName',
'RCTrack',
'RCDate',
'RaceState',
'Division',
'Class',
'RaceBred',
'StateBred',
'RaceSex',
'RaceAge',
'HiClaim',
'LoClaim',
'Inner',
'GradedRace',
'GradedRaceDesc',
'SimTrack',
    'RaceType',
'SimRace',
'TrackRecord',
'DayOfWeek',
'TrkAbbrev',
'DistUnit','TimeUnit'])

# %%
slim_df
# Out:
#     RCRace  Starters  Purse  Distance Surface PostTime     LongClass  \
# 0        1        12   32.0       6.0       D    12:00    Alw 40000s
# 1        2        14   60.0       6.0       D    12:32  Md Sp Wt 60k
# 2        3        14   61.0       6.0       D     1:04  Alw 61000N$Y
# 3        4        14   60.0       6.0       D     1:36  Md Sp Wt 60k
# 4        5        13   62.0       8.5       D     2:10      OC 75k/C
# 5        6        14   60.0       9.0       D     2:44  Md Sp Wt 60k
# 6        7        14   61.0       8.5       D     3:16     OC 100k/C
# 7        8        14   61.0       8.5       D     3:47  Alw 61000N$Y
# 8        9        14   62.0       8.5       D     4:19    OC 40k/N$Y
# 9       10        14   61.0       8.5       D     4:54    OC 80k/N$Y
# 10      11        11  500.0       9.0       D     5:29   ArkDerby-G1
# 11      12        14  600.0       9.0       D     6:04   OaklawnH-G2
# 12      13        11  500.0       9.0       D     6:43   ArkDerby-G1
# 13      14        14   50.0      14.0       D     7:14    Alw 10000s
#
#                                            Conditions
# 0   STARTER ALLOWANCE. Purse $32,000  FOR FILLIES ...
# 1   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 2   ALLOWANCE. Purse $61,000  FOR ARKANSAS BRED (W...
# 3   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 4   ALLOWANCE OPTIONAL CLAIMING. Purse $62,000  FO...
# 5   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 6   ALLOWANCE OPTIONAL CLAIMING. Purse $61,000  FO...
# 7   ALLOWANCE. Purse $61,000  FOR THREE YEAR OLDS ...
# 8   ALLOWANCE OPTIONAL CLAIMING. Purse $62,000  FO...
# 9   ALLOWANCE OPTIONAL CLAIMING. Purse $61,000  FO...
# 10  ARKANSAS DERBY. Purse $500,000  THREE YEAR OLD...
# 11  OAKLAWN H.. Purse $600,000  FOUR YEAR OLDS AND...
# 12  ARKANSAS DERBY. Purse $500,000  THREE YEAR OLD...
# 13  STARTER ALLOWANCE. Purse $50,000  FOR THREE YE...

# %%
slim_df['Purse'] = slim_df['Purse']*10

# %%
slim_df
# Out:
#     RCRace  Starters     Purse  Distance Surface PostTime     LongClass  \
# 0        1        12   32000.0       6.0       D    12:00    Alw 40000s
# 1        2        14   60000.0       6.0       D    12:32  Md Sp Wt 60k
# 2        3        14   61000.0       6.0       D     1:04  Alw 61000N$Y
# 3        4        14   60000.0       6.0       D     1:36  Md Sp Wt 60k
# 4        5        13   62000.0       8.5       D     2:10      OC 75k/C
# 5        6        14   60000.0       9.0       D     2:44  Md Sp Wt 60k
# 6        7        14   61000.0       8.5       D     3:16     OC 100k/C
# 7        8        14   61000.0       8.5       D     3:47  Alw 61000N$Y
# 8        9        14   62000.0       8.5       D     4:19    OC 40k/N$Y
# 9       10        14   61000.0       8.5       D     4:54    OC 80k/N$Y
# 10      11        11  500000.0       9.0       D     5:29   ArkDerby-G1
# 11      12        14  600000.0       9.0       D     6:04   OaklawnH-G2
# 12      13        11  500000.0       9.0       D     6:43   ArkDerby-G1
# 13      14        14   50000.0      14.0       D     7:14    Alw 10000s
#
#                                            Conditions
# 0   STARTER ALLOWANCE. Purse $32,000  FOR FILLIES ...
# 1   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 2   ALLOWANCE. Purse $61,000  FOR ARKANSAS BRED (W...
# 3   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 4   ALLOWANCE OPTIONAL CLAIMING. Purse $62,000  FO...
# 5   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 6   ALLOWANCE OPTIONAL CLAIMING. Purse $61,000  FO...
# 7   ALLOWANCE. Purse $61,000  FOR THREE YEAR OLDS ...
# 8   ALLOWANCE OPTIONAL CLAIMING. Purse $62,000  FO...
# 9   ALLOWANCE OPTIONAL CLAIMING. Purse $61,000  FO...
# 10  ARKANSAS DERBY. Purse $500,000  THREE YEAR OLD...
# 11  OAKLAWN H.. Purse $600,000  FOUR YEAR OLDS AND...
# 12  ARKANSAS DERBY. Purse $500,000  THREE YEAR OLD...
# 13  STARTER ALLOWANCE. Purse $50,000  FOR THREE YE...

# %%
slim_df['Purse'] = slim_df['Purse'].apply(lambda x: "${:.1f}k".format((x/1000)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-7167631a1486> in <module>
# ----> 1 slim_df['Purse'] = slim_df['Purse'].apply(lambda x: "${:.1f}k".format((x/1000)))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-31-7167631a1486> in <lambda>(x)
# ----> 1 slim_df['Purse'] = slim_df['Purse'].apply(lambda x: "${:.1f}k".format((x/1000)))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
slim_df
# Out:
#     RCRace  Starters    Purse  Distance Surface PostTime     LongClass  \
# 0        1        12   $32.0k       6.0       D    12:00    Alw 40000s
# 1        2        14   $60.0k       6.0       D    12:32  Md Sp Wt 60k
# 2        3        14   $61.0k       6.0       D     1:04  Alw 61000N$Y
# 3        4        14   $60.0k       6.0       D     1:36  Md Sp Wt 60k
# 4        5        13   $62.0k       8.5       D     2:10      OC 75k/C
# 5        6        14   $60.0k       9.0       D     2:44  Md Sp Wt 60k
# 6        7        14   $61.0k       8.5       D     3:16     OC 100k/C
# 7        8        14   $61.0k       8.5       D     3:47  Alw 61000N$Y
# 8        9        14   $62.0k       8.5       D     4:19    OC 40k/N$Y
# 9       10        14   $61.0k       8.5       D     4:54    OC 80k/N$Y
# 10      11        11  $500.0k       9.0       D     5:29   ArkDerby-G1
# 11      12        14  $600.0k       9.0       D     6:04   OaklawnH-G2
# 12      13        11  $500.0k       9.0       D     6:43   ArkDerby-G1
# 13      14        14   $50.0k      14.0       D     7:14    Alw 10000s
#
#                                            Conditions
# 0   STARTER ALLOWANCE. Purse $32,000  FOR FILLIES ...
# 1   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 2   ALLOWANCE. Purse $61,000  FOR ARKANSAS BRED (W...
# 3   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 4   ALLOWANCE OPTIONAL CLAIMING. Purse $62,000  FO...
# 5   MAIDEN SPECIAL WEIGHT. Purse $60,000  FOR MAID...
# 6   ALLOWANCE OPTIONAL CLAIMING. Purse $61,000  FO...
# 7   ALLOWANCE. Purse $61,000  FOR THREE YEAR OLDS ...
# 8   ALLOWANCE OPTIONAL CLAIMING. Purse $62,000  FO...
# 9   ALLOWANCE OPTIONAL CLAIMING. Purse $61,000  FO...
# 10  ARKANSAS DERBY. Purse $500,000  THREE YEAR OLD...
# 11  OAKLAWN H.. Purse $600,000  FOUR YEAR OLDS AND...
# 12  ARKANSAS DERBY. Purse $500,000  THREE YEAR OLD...
# 13  STARTER ALLOWANCE. Purse $50,000  FOR THREE YE...

# %%
##Done
