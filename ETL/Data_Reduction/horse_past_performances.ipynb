# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

# %%
fullcard = pd.read_csv('../data/Op_200502_hr.csv')

# %%
fullcard
# Out:
#      RCTrack      RCDate  RCRace             Horse FD  Foreign        Date  \
# 0         OP  05/02/2020       1  Timely Tradition  D      NaN  03/15/2020
# 1         OP  05/02/2020       1  Timely Tradition  D      NaN  01/26/2020
# 2         OP  05/02/2020       1  Timely Tradition  D      NaN  12/15/2019
# 3         OP  05/02/2020       1  Timely Tradition  D      NaN  10/05/2019
# 4         OP  05/02/2020       1  Timely Tradition  D      NaN  07/18/2019
# ...      ...         ...     ...               ... ..      ...         ...
# 2178      OP  05/02/2020      14        River Echo  F      NaN  09/25/2016
# 2179      OP  05/02/2020      14        River Echo  F      NaN  08/11/2016
# 2180      OP  05/02/2020      14        River Echo  F      NaN  07/15/2016
# 2181      OP  05/02/2020      14        River Echo  F      NaN  09/30/2015
# 2182      OP  05/02/2020      14        River Echo  F      NaN  09/19/2015
#
# ...

# %%
r11horses = fullcard[fullcard.RCRace == 11]

# %%
r11horses
# Out:
#      RCTrack      RCDate  RCRace               Horse FD  Foreign        Date  \
# 1425      OP  05/02/2020      11           Charlatan  D      NaN  03/14/2020
# 1426      OP  05/02/2020      11           Charlatan  D      NaN  02/16/2020
# 1427      OP  05/02/2020      11     My Friends Beer  D      NaN  04/11/2020
# 1428      OP  05/02/2020      11     My Friends Beer  D      NaN  03/14/2020
# 1429      OP  05/02/2020      11     My Friends Beer  D      NaN  02/02/2020
# 1430      OP  05/02/2020      11     My Friends Beer  D      NaN  01/01/2020
# 1431      OP  05/02/2020      11     My Friends Beer  D      NaN  12/14/2019
# 1432      OP  05/02/2020      11     My Friends Beer  D      NaN  11/14/2019
# 1433      OP  05/02/2020      11     My Friends Beer  D      NaN  11/02/2019
# 1434      OP  05/02/2020      11     My Friends Beer  D      NaN  10/14/2019
# 1435      OP  05/02/2020      11             Mo Mosa  D      NaN  04/11/2020
# ...

# %%
for col in r11horses.columns: 
    print(col)
# Out:
# RCTrack
# RCDate
# RCRace
# Horse
# FD
# Foreign
# Date
# Track
# Race
# Surface
# TimeformCode
# Inner
# Distance
# Class
# LongClass
# ClaimPrice
# Purse
# TrkCond
# RaceSex
# RaceAge
# StateBred
# Starters
# FirstFraction
# SecondFraction
# ThirdFraction
# FourthFraction
# FifthFraction
# SixthFraction
# FinalTime
# FirstHorse
# SecondHorse
# ThirdHorse
# FirstWeight
# SecondWeight
# ThirdWeight
# FirstLenAdj
# SecondLenAdj
# ThirdLenAdj
# GradedRace
# GradedRaceDesc
# ForeignCourse
# PostPosition
# FirstCall
# FirstCallLenAdj
# SecondCall
# SecondCallLenAdj
# ThirdCall
# ThirdCallLenAdj
# FourthCall
# FourthCallLenAdj
# StrCall
# StrCallLenAdj
# FinalCall
# FinalCallLenAdj
# DQ
# DH
# DQPlace
# Beyer
# Weight
# Apprentice
# Comment
# LongComment
# Odds
# OddsPosition
# Claimed
# Lasix
# Bute
# Blinker
# Bandage
# AltEquipment
# Jockey
# Trainer
# Entries
# TrackVariant
# SpeedRating
# Breed
# Owner
# DistUnit
# TimeUnit
# LoPrice
# TrainYear
# TrainStarts
# TrainWins
# ...

# %%
condense_pp = r11horses[[
'Date',
'Horse',
'Jockey',
'Distance',
'FinalCall',
'Beyer',
'Odds',
'Starters',
'Trainer',
'FirstFracHdths',
'SecondFracHdths',
'ThirdFracHdths',
'FourthFracHdths',
'FinalTimeHdths'
]].copy()

# %%
condense_pp
# Out:
#                    Horse            Jockey        Date  Distance  FinalCall  \
# 1425           Charlatan        Van Dyke D  03/14/2020      8.00          1
# 1426           Charlatan        Van Dyke D  02/16/2020      6.00          1
# 1427     My Friends Beer          Cannon D  04/11/2020      8.00          3
# 1428     My Friends Beer           Lynch F  03/14/2020      8.50          2
# 1429     My Friends Beer           Lynch F  02/02/2020      8.00          2
# 1430     My Friends Beer           Lynch F  01/01/2020      8.00          1
# 1431     My Friends Beer         Russell S  12/14/2019      7.00          2
# 1432     My Friends Beer         Russell S  11/14/2019      8.00          3
# 1433     My Friends Beer           Lynch F  11/02/2019      6.00          5
# 1434     My Friends Beer           Lynch F  10/14/2019      5.50          4
# 1435             Mo Mosa      Rocco J S Jr  04/11/2020      8.00          3
# ...
