# %%
import pandas as pd
import pymongo
import dns
from pymongo import MongoClient
import os

# %%
client = MongoClient("mongodb+srv://dbUser:OxTrot2020@cluster0-lfpvw.azure.mongodb.net/test?retryWrites=true&w=majority")

# %%
# !ls
# Out:
# data
# Data_Reduction
# debug.log
# Gp_200502_CF.json
# images
# Importing all of the data to MongoDB.ipynb
# Sandbox to clean the data.ipynb
# Testing the mongoDB connection.ipynb

# %%
# !cd data  && ls
# Out:
# Gp_200502_CF.csv
# Gp_200502_cl.csv
# Gp_200502_h.csv
# Gp_200502_hr.csv
# Gp_200502_JF.csv
# Gp_200502_r.csv
# Gp_200502_s.csv
# Gp_200502_t.csv
# Gp_200502_TF.csv
# Gp_200502_u.csv
# Gp_200502_w.csv
# horses.csv
# La_200502_CF.csv
# La_200502_cl.csv
# La_200502_h.csv
# La_200502_hr.csv
# La_200502_JF.csv
# La_200502_r.csv
# La_200502_s.csv
# La_200502_t.csv
# La_200502_TF.csv
# La_200502_u.csv
# La_200502_w.csv
# Op_200502_CF.csv
# Op_200502_cl.csv
# Op_200502_h.csv
# Op_200502_hr.csv
# Op_200502_JF.csv
# Op_200502_r.csv
# Op_200502_s.csv
# Op_200502_t.csv
# Op_200502_TF.csv
# Op_200502_u.csv
# Op_200502_w.csv
# op_races.csv
# race_11.csv
# Rp_200502_CF.csv
# Rp_200502_cl.csv
# Rp_200502_h.csv
# Rp_200502_hr.csv
# Rp_200502_JF.csv
# Rp_200502_r.csv
# Rp_200502_s.csv
# Rp_200502_t.csv
# Rp_200502_TF.csv
# Rp_200502_u.csv
# Rp_200502_w.csv
# Tam200502_CF.csv
# Tam200502_cl.csv
# Tam200502_h.csv
# Tam200502_hr.csv
# Tam200502_JF.csv
# Tam200502_r.csv
# Tam200502_s.csv
# ...

# %%
horses_df = pd.read_csv(os.path.join('data','horses.csv'))
horses_df
# Out:
#           Date               Horse            Jockey  Distance  FinalCall  \
# 0   03/14/2020           Charlatan        Van Dyke D      8.00          1
# 1   02/16/2020           Charlatan        Van Dyke D      6.00          1
# 2   04/11/2020     My Friends Beer          Cannon D      8.00          3
# 3   03/14/2020     My Friends Beer           Lynch F      8.50          2
# 4   02/02/2020     My Friends Beer           Lynch F      8.00          2
# 5   01/01/2020     My Friends Beer           Lynch F      8.00          1
# 6   12/14/2019     My Friends Beer         Russell S      7.00          2
# 7   11/14/2019     My Friends Beer         Russell S      8.00          3
# 8   11/02/2019     My Friends Beer           Lynch F      6.00          5
# 9   10/14/2019     My Friends Beer           Lynch F      5.50          4
# 10  04/11/2020             Mo Mosa      Rocco J S Jr      8.00          3
# 11  03/07/2020             Mo Mosa         Morales P      8.50         12
# ...

# %%
op_races_df = pd.read_csv(os.path.join('data','op_races.csv'))
op_races_df
# Out:
#     RCRace  Starters  Purse  Distance Surface PostTime     LongClass  \
# 0        1        12  $0.3k       6.0       D    12:00    Alw 40000s
# 1        2        14  $0.6k       6.0       D    12:32  Md Sp Wt 60k
# 2        3        14  $0.6k       6.0       D     1:04  Alw 61000N$Y
# 3        4        14  $0.6k       6.0       D     1:36  Md Sp Wt 60k
# 4        5        13  $0.6k       8.5       D     2:10      OC 75k/C
# 5        6        14  $0.6k       9.0       D     2:44  Md Sp Wt 60k
# 6        7        14  $0.6k       8.5       D     3:16     OC 100k/C
# 7        8        14  $0.6k       8.5       D     3:47  Alw 61000N$Y
# 8        9        14  $0.6k       8.5       D     4:19    OC 40k/N$Y
# 9       10        14  $0.6k       8.5       D     4:54    OC 80k/N$Y
# 10      11        11  $5.0k       9.0       D     5:29   ArkDerby-G1
# 11      12        14  $6.0k       9.0       D     6:04   OaklawnH-G2
# 12      13        11  $5.0k       9.0       D     6:43   ArkDerby-G1
# ...

# %%
race_11_df = pd.read_csv(os.path.join('data','race_11.csv'))
race_11_df
# Out:
#     PostPosition               Horse            Trainer         Jockey  \
# 0              1           Charlatan        Baffert Bob       Garcia M
# 1              2     My Friends Beer   O'Dwyer Jeremiah       Cannon D
# 2              3             Mo Mosa    Maker Michael J    Carmouche K
# 3              4   Gouverneur Morris    Pletcher Todd A  Velazquez J R
# 4              5       Jungle Runner  Asmussen Steven M       Baze T C
# 5              6      Shooters Shoot       Eurton Peter       Talamo J
# 6              7       Wrecking Crew       Miller Peter         Prat F
# 7              8         Anneau d'Or      Wright Blaine  Hernandez J J
# 8              9  Winning Impression     Stewart Dallas   Leparoux J R
# 9             10         Crypto Cash   McPeek Kenneth G    Lanerie C J
# 10            11               Basin  Asmussen Steven M   Santana R Jr
#
#                   Sire              Dam                               Owner  \
# ...

# %%
race_track_info_df = pd.read_json(os.path.join("..","Leaflet prototype","race_tracks.json"))
race_track_info_df
# Out:
#                  lat                lon                            nameLong  \
# 0   40.6729621887207  -73.8316116333008                  Aqueduct Racetrack
# 1   39.6277236938477  -104.686370849609                       Arapahoe Park
# 2   42.0924377441406  -88.0101776123047  Arlington International Racecourse
# 3   49.8894386291504  -97.3292083740234                    Assiniboia Downs
# 4   39.4524955749512  -74.6470794677734           Atlantic City Race Course
# ..               ...                ...                                 ...
# 61  33.6399078369141  -112.091743469238                       Turf Paradise
# 62   39.024284362793  -84.6350860595703                        Turfway Park
# 63  36.3145904541016  -95.5252075195313                   Will Rogers Downs
# 64  43.7107276916504  -79.6034545898438                            Woodbine
# 65  32.7511177062988  -103.187713623047                            Zia Park
#
#    nameShort
# 0        AQU
# 1        ARP
# ...

# %%
def mongo_upload(collection_df, collection_string):
    # Connect to MongoDB
    data = collection_df
    client =  MongoClient("mongodb+srv://dbUser:OxTrot2020@cluster0-lfpvw.azure.mongodb.net/test?retryWrites=true&w=majority")
    db = client['website_db']
    collection = db[f'{collection_string}']
    data.reset_index(inplace=True)
    data_dict = data.to_dict("records")# Insert collection
    collection.insert_many(data_dict)

# %%
# !cd ../"Leaflet prototype" && pwd && ls
# Out:
# /c/Users/Ayman/Desktop/Bootcamp/Bootcamp-Projects/officious-ox-project-2/Leaflet prototype
# chromedriver.exe
# Data Mining the locations.ipynb
# debug.log
# leaflet-flask
# race_tracks.json
# website

# %%
mongo_upload(race_track_info_df)
# Out:
# ---------------------------------------------------------------------------
# InvalidName                               Traceback (most recent call last)
# <ipython-input-29-bd138963ee06> in <module>
# ----> 1 mongo_upload(race_track_info_df)
#
# <ipython-input-28-baccfb2eb2f9> in mongo_upload(collection_name)
#       4     client =  MongoClient("mongodb+srv://dbUser:OxTrot2020@cluster0-lfpvw.azure.mongodb.net/test?retryWrites=true&w=majority")
#       5     db = client['website_db']
# ----> 6     collection = db[f'{collection_name}']
#       7     data.reset_index(inplace=True)
#       8     data_dict = data.to_dict("records")# Insert collection
#
# ~\Anaconda3\lib\site-packages\pymongo\database.py in __getitem__(self, name)
#     298           - `name`: the name of the collection to get
#     299         """
# --> 300         return Collection(self, name)
#     301
#     302     def get_collection(self, name, codec_options=None, read_preference=None,
#
# ...
