# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import os
from fractions import Fraction

# %%
df = pd.read_csv(os.path.join('3year_cd_data_train.csv'))

# %%
def cleaner(df):
    df = df[df.tvghorseaverageclassrating != 0]
    df = df[df.tvghorseweight > 100]
    df['won'] = np.where(df['winpayout']>0,1,0)
    df = df[df.scratched == 0]
    df = df[df.currentodds != 'SC']
    df.drop_duplicates(keep='first', inplace=False)
    return df

# %%
df_cleaned = cleaner(df)

# %%
df_cleaned
# Out:
#         racedater tvgtrackcode  race  bettinginterestnumber  \
# 1      2018-05-02           cd     4                      7
# 2      2018-05-02           cd     4                      6
# 3      2018-05-02           cd     4                      5
# 4      2018-05-02           cd     4                      4
# 5      2018-05-02           cd     4                      3
# ...           ...          ...   ...                    ...
# 18142  2020-06-18           cd     9                      4
# 18143  2020-06-18           cd     9                      5
# 18144  2020-06-18           cd     9                      6
# 18145  2020-06-18           cd     9                      7
# 18146  2020-06-18           cd     9                      8
#
#                  horsename  morninglineodds finalodds  tvghorseweight  \
# 1         bern' james bern              2.0       0.6             119
# 2                 catinati             20.0        30             119
# 3                    montu              6.0        18             119
# 4      zambian dream (chi)             10.0         6             119
# 5         hollywood critic              2.5         3             119
# ...                    ...              ...       ...             ...
# 18142      flying scotsman             15.0        14             122
# 18143     argentello (ire)             20.0        23             122
# 18144   extrordinary jerry              8.0        14             122
# 18145              penalty              4.5       9/2             122
# 18146          cullum road              5.0        12             122
#
#       tvghorsedamsirename  tvghorseage  ... tvghorsenumberofstarts  \
# 1                   gulch            7  ...                     21
# 2           with approval            5  ...                      1
# 3        deputy commander            4  ...                      0
# 4         doneraile court            7  ...                      7
# 5            kaldoun (fr)            6  ...                      3
# ...                   ...          ...  ...                    ...
# 18142       french deputy            4  ...                      6
# 18143             selkirk            5  ...                      9
# 18144   successful appeal            5  ...                      9
# 18145        empire maker            5  ...                      8
# 18146      indian charlie            5  ...                     22
#
#        tvghorsepowerrating  tvghorseaveragespeed  tvghorseaverageclassrating  \
# 1                    113.4                   100                         108
# 2                     75.0                    83                          93
# 3                     63.6                    73                          87
# 4                     58.9                    63                         108
# 5                     91.8                    91                         100
# ...                    ...                   ...                         ...
# 18142                101.2                    91                         108
# 18143                 80.2                    88                         109
# 18144                 85.7                    99                         105
# 18145                107.0                   101                         104
# 18146                 93.5                   101                         111
#
#        currentodds  winpayout  placepayout showpayout  scratched  won
# 1              3/5        0.0          0.0        2.2          0    0
# 2               30        0.0          0.0        0.0          0    0
# 3               18        0.0         12.0        5.2          0    0
# 4                6        0.0          0.0        0.0          0    0
# 5                3        8.6          4.4        2.8          0    1
# ...            ...        ...          ...        ...        ...  ...
# 18142           14        0.0          0.0        0.0          0    0
# 18143           23        0.0          0.0        0.0          0    0
# 18144           14        0.0          0.0        0.0          0    0
# 18145          9/2        0.0          0.0        0.0          0    0
# 18146           12        0.0          0.0        7.4          0    0
#
# [13750 rows x 23 columns]

# %%
w = [i for i in df_cleaned.currentodds]
# w

# %%
y = []

for i in df_cleaned.currentodds:
    if len(i) >= 3:
        q = float(Fraction(int(i[0]),int(i[2])))
        y.append(q)
    else:
        q =float(i)
        y.append(q)
        
df_cleaned.currentodds = y

# %%
# good_bet = []

# for i in range(len(df_cleaned.won)):
#     odds = df_cleaned.loc[] 
#     won = 
    #     if i == 1 and j > 1:
#         print('good')
#     elif i == 1 and j < 1 and j > 0:
#         print('bad')
#     else:
#         print('bad')

# %%
df_cleaned.count()
# Out:
# racedater                     13750
# tvgtrackcode                  13750
# race                          13750
# bettinginterestnumber         13750
# horsename                     13750
# morninglineodds               13750
# finalodds                     13750
# tvghorseweight                13750
# tvghorsedamsirename           13750
# tvghorseage                   13750
# tvghorsesex                   13750
# tvghorsedaysoff               13750
# tvghorsenumberofwins          13750
# tvghorsenumberofstarts        13750
# tvghorsepowerrating           13750
# tvghorseaveragespeed          13750
# tvghorseaverageclassrating    13750
# currentodds                   13750
# winpayout                     13750
# placepayout                   13750
# showpayout                    13750
# scratched                     13750
# won                           13750
# dtype: int64

# %%
df_cleaned.sort_values('racedater')
# Out:
#         racedater tvgtrackcode  race  bettinginterestnumber  \
# 713    2018-05-01           cd     2                      5
# 64     2018-05-01           cd     5                      4
# 62     2018-05-01           cd     5                      6
# 61     2018-05-01           cd     5                      7
# 60     2018-05-01           cd     5                      8
# ...           ...          ...   ...                    ...
# 17781  2020-06-27           cd     8                      5
# 17780  2020-06-27           cd     8                      4
# 17779  2020-06-27           cd     8                      3
# 17874  2020-06-27           cd    11                      9
# 17843  2020-06-27           cd    10                      6
#
#                 horsename  morninglineodds finalodds  tvghorseweight  \
# 713            rocky roma             12.0        14             118
# 64        i am miss brown              3.5         6             118
# 62     gracequinnannamady             20.0        24             118
# 61          north of eden              2.0         1             118
# 60          wood not mind              6.0        25             118
# ...                   ...              ...       ...             ...
# 17781       herd immunity              4.5        12             120
# 17780          hyperfocus              4.0         5             120
# 17779              gatsby              4.0         6             120
# 17874          eve of war             12.0        17             118
# 17843     by my standards              2.5       9/5             122
#
#       tvghorsedamsirename  tvghorseage  ... tvghorsenumberofstarts  \
# 713                  awad            3  ...                      9
# 64          formal dinner            8  ...                     41
# 62            half a year            6  ...                     23
# 61              kingmambo            5  ...                     12
# 60            mr. greeley            6  ...                     29
# ...                   ...          ...  ...                    ...
# 17781         malibu moon            2  ...                      1
# 17780     hat trick (jpn)            2  ...                      1
# 17779           aldebaran            2  ...                      1
# 17874          broken vow            3  ...                      2
# 17843            muqtarib            4  ...                      8
#
#        tvghorsepowerrating  tvghorseaveragespeed  tvghorseaverageclassrating  \
# 713                   51.3                    50                          67
# 64                    66.3                    66                          82
# 62                    59.3                    62                          77
# 61                    76.2                    72                          77
# 60                    69.0                    65                          75
# ...                    ...                   ...                         ...
# 17781                 98.0                    92                          90
# 17780                 86.6                    83                          82
# 17779                 86.1                    83                          82
# 17874                 95.6                    89                          91
# 17843                108.6                    98                         102
#
#        currentodds  winpayout  placepayout  showpayout  scratched  won
# 713           14.0        0.0          0.0         0.0          0    0
# 64             6.0        0.0          0.0         0.0          0    0
# 62            24.0        0.0          0.0         0.0          0    0
# 61             1.0        0.0          0.0         2.1          0    0
# 60            25.0        0.0          0.0         0.0          0    0
# ...            ...        ...          ...         ...        ...  ...
# 17781         12.0        0.0          0.0         4.6          0    0
# 17780          5.0        0.0          0.0         0.0          0    0
# 17779          6.0        0.0          0.0         0.0          0    0
# 17874         17.0        0.0          0.0         0.0          0    0
# 17843          1.8        0.0          3.2         3.0          0    0
#
# [13750 rows x 23 columns]

# %%
df_cleaned.to_csv(os.path.join('..','Data_to_upload','total.csv'), index=False)

# %%
train_df = pd.read_csv(os.path.join('3year_cd_data_train.csv'))
test_df = pd.read_csv(os.path.join('tvg_cd_data_test.csv'))

# %%
len(train_df)
# Out:
# 18148

# %%
len(test_df)
# Out:
# 2229

# %%
def cleaner(df):
    df = df[df.tvghorseaverageclassrating != 0]
    df = df[df.tvghorseweight > 100]
    df['won'] = np.where(df['winpayout']>0,1,0)
    df = df[df.scratched == 0]
    df = df[df.currentodds == 'SC']
    df.drop_duplicates(keep='first', inplace=False)
    return df

# %%
train_cleaned = cleaner(train_df)
train_cleaned = train_cleaned.drop('finalodds',1)
train_cleaned.dtypes
# Out:
# racedater                      object
# tvgtrackcode                   object
# race                            int64
# bettinginterestnumber           int64
# horsename                      object
# morninglineodds               float64
# tvghorseweight                  int64
# tvghorsedamsirename            object
# tvghorseage                     int64
# tvghorsesex                    object
# tvghorsedaysoff                 int64
# tvghorsenumberofwins            int64
# tvghorsenumberofstarts          int64
# tvghorsepowerrating           float64
# tvghorseaveragespeed            int64
# tvghorseaverageclassrating      int64
# currentodds                    object
# winpayout                     float64
# placepayout                   float64
# showpayout                    float64
# scratched                       int64
# won                             int32
# dtype: object

# %%
test_df = test_df.rename(columns={'currentodds.1':'currentodds'})
test_cleaned = cleaner(test_df)
print(len(test_cleaned))
test_cleaned = 
test_cleaned = test_cleaned.drop_duplicates()

test_cleaned.dtypes
# Out:
#   File "<ipython-input-56-fa41d940b75f>", line 4
#     test_cleaned =
#                    ^
# SyntaxError: invalid syntax

# %%
train_cleaned.to_csv('train.csv',index=False)
test_cleaned.to_csv('test.csv',index=False)

# %%
train_cleaned.columns
# Out:
# Index(['racedater', 'tvgtrackcode', 'race', 'bettinginterestnumber',
#        'horsename', 'morninglineodds', 'tvghorseweight', 'tvghorsedamsirename',
#        'tvghorseage', 'tvghorsesex', 'tvghorsedaysoff', 'tvghorsenumberofwins',
#        'tvghorsenumberofstarts', 'tvghorsepowerrating', 'tvghorseaveragespeed',
#        'tvghorseaverageclassrating', 'currentodds', 'winpayout', 'placepayout',
#        'showpayout', 'scratched', 'won'],
#       dtype='object')

# %%
test_cleaned.columns
# Out:
# Index(['racedater', 'tvgtrackcode', 'race', 'bettinginterestnumber',
#        'horsename', 'morninglineodds', 'currentodds', 'tvghorseweight',
#        'tvghorsedamsirename', 'tvghorseage', 'tvghorsesex', 'tvghorsedaysoff',
#        'tvghorsenumberofwins', 'tvghorsenumberofstarts', 'tvghorsepowerrating',
#        'tvghorseaveragespeed', 'tvghorseaverageclassrating', 'currentodds',
#        'winpayout', 'placepayout', 'showpayout', 'scratched', 'won'],
#       dtype='object')

# %%
train_cleaned.columns == test_cleaned.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0ecad6ce3850> in <module>
# ----> 1 train_cleaned.columns == test_cleaned.columns
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in cmp_method(self, other)
#     103         if isinstance(other, (np.ndarray, Index, ABCSeries, ExtensionArray)):
#     104             if other.ndim > 0 and len(self) != len(other):
# --> 105                 raise ValueError("Lengths must match to compare")
#     106
#     107         if is_object_dtype(self) and isinstance(other, ABCCategorical):
#
# ValueError: Lengths must match to compare

# %%
import datetime
frames = [train_cleaned, test_cleaned]
total = pd.concat(frames)
total['racedater'] =  pd.to_datetime(total['racedater'], format='%Y-%m-%d')
print(len(total))
total = cleaner(total)
total = total.drop_duplicates()
print(len(total))
total.to_csv('total.csv', index=False)

# %%
total.dtypes
